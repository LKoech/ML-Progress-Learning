# %% [markdown]
# <a href="https://colab.research.google.com/github/LKoech/ML-Progress-Learning/blob/main/DataExploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header = None)

# %%
data.head(5)
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
data.sample(20)
# Out:
#        0    1    2    3                4
# 147  6.5  3.0  5.2  2.0   Iris-virginica
# 25   5.0  3.0  1.6  0.2      Iris-setosa
# 10   5.4  3.7  1.5  0.2      Iris-setosa
# 146  6.3  2.5  5.0  1.9   Iris-virginica
# 109  7.2  3.6  6.1  2.5   Iris-virginica
# 35   5.0  3.2  1.2  0.2      Iris-setosa
# 8    4.4  2.9  1.4  0.2      Iris-setosa
# 81   5.5  2.4  3.7  1.0  Iris-versicolor
# 32   5.2  4.1  1.5  0.1      Iris-setosa
# 23   5.1  3.3  1.7  0.5      Iris-setosa
# 0    5.1  3.5  1.4  0.2      Iris-setosa
# 124  6.7  3.3  5.7  2.1   Iris-virginica
# 119  6.0  2.2  5.0  1.5   Iris-virginica
# 86   6.7  3.1  4.7  1.5  Iris-versicolor
# 1    4.9  3.0  1.4  0.2      Iris-setosa
# 95   5.7  3.0  4.2  1.2  Iris-versicolor
# 118  7.7  2.6  6.9  2.3   Iris-virginica
# 110  6.5  3.2  5.1  2.0   Iris-virginica
# 112  6.8  3.0  5.5  2.1   Iris-virginica
# 46   5.1  3.8  1.6  0.2      Iris-setosa

# %%
data.columns=['sepal length','sepal width','petal length','petal width','class']
data
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Next, we can explore the data by computing some stastistical measures.

# %%
from pandas.api.types import is_numeric_dtype

# %%
for col in data.columns:
  if is_numeric_dtype(data[col]):
    print('%s:'%(col))
    print('\t Mean = %.2f '% data[col].mean() )
    print('\t Standard Deviation = %.2f '% data[col].std() )
    print('\t Min = %.2f '% data[col].min() )
    print('\t Max = %.2f '% data[col].max() )
    print('\t Median = %.2f '% data[col].median() )
# Out:
# sepal length:
# 	 Mean = 5.84
# 	 Standard Deviation = 0.83
# 	 Min = 4.30
# 	 Max = 7.90
# 	 Median = 5.80
# sepal width:
# 	 Mean = 3.05
# 	 Standard Deviation = 0.43
# 	 Min = 2.00
# 	 Max = 4.40
# 	 Median = 3.00
# petal length:
# 	 Mean = 3.76
# 	 Standard Deviation = 1.76
# 	 Min = 1.00
# 	 Max = 6.90
# 	 Median = 4.35
# petal width:
# 	 Mean = 1.20
# 	 Standard Deviation = 0.76
# 	 Min = 0.10
# 	 Max = 2.50
# 	 Median = 1.30

# %%
data.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
